# %% [markdown]
# <a href="https://colab.research.google.com/github/maeyda-masroor/25_project_python/blob/days/QRCODE-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import qrcode
data = "Dont forget to subscribe"
img = qrcode.make(data)
img.save("test.png")

# %%
# !pip install qrcode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.5 MB/s eta 0:00:00
# ...
